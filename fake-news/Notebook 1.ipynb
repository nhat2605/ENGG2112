# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# # Overview

# %% [markdown]
# ### Goal

# %% [markdown]
# Broad: Train a machine learning model that can determine whether an article online is real or fake.

# %% [markdown]
# Specific Objective:

# %% [markdown]
# Clean our data correctly (learn methods such as Stemming and Lemmatization)

# %% [markdown]
# Perform Feature Vectorization (learn TF-IDF, N-gram, Sentimental analysis)

# %% [markdown]
# Train the models (learn fine tuning models: hyper-parameters)

# %% [markdown]
# Evaluation (Determine which one of the models are the best)Real world testing by deploying the models (Learn how to deploy the model)

# %% [markdown]
# ### Dataset

# %% [markdown]
# train.csv: A full training dataset with the following attributes:

# %% [markdown]
# id: unique id for a news article

# %% [markdown]
# title: the title of a news article

# %% [markdown]
# author: author of the news articletext: the text of the article; could be incomplete

# %% [markdown]
# label: a label that marks the article as potentially unreliable

# %% [markdown]
# 1: unreliable

# %% [markdown]
# 0: reliable

# %% [markdown]
# Session 1:

# %% [markdown]
# Stuff to do

# %% [markdown]
# 1. Cleaning data

# %%
df = pd.read_csv("train.csv")
df
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# 2                             Consortiumnews.com
# 3                                Jessica Purkiss
# 4                                 Howard Portnoy
# ...                                          ...
# 20795                              Jerome Hudson
# 20796                           Benjamin Hoffman
# 20797  Michael J. de la Merced and Rachel Abrams
# 20798                                Alex Ansary
# 20799                              David Swanson
#
#                                                     text  label
# 0      House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1      Ever get the feeling your life circles the rou...      0
# 2      Why the Truth Might Get You Fired October 29, ...      1
# 3      Videos 15 Civilians Killed In Single US Airstr...      1
# 4      Print \r\nAn Iranian woman has been sentenced ...      1
# ...                                                  ...    ...
# 20795  Rapper T. I. unloaded on black celebrities who...      0
# 20796  When the Green Bay Packers lost to the Washing...      0
# 20797  The Macy’s of today grew from the union of sev...      0
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...      1
# 20799    David Swanson is an author, activist, journa...      1
#
# [20800 rows x 5 columns]

# %%
df['author'].fillna('Unknown', inplace=True)
df['title'].fillna('Ambiguous', inplace=True)
df['text'].fillna('Ambiguous', inplace=True)
df.drop_duplicates(inplace=True)
df
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# 2                             Consortiumnews.com
# 3                                Jessica Purkiss
# 4                                 Howard Portnoy
# ...                                          ...
# 20795                              Jerome Hudson
# 20796                           Benjamin Hoffman
# 20797  Michael J. de la Merced and Rachel Abrams
# 20798                                Alex Ansary
# 20799                              David Swanson
#
#                                                     text  label
# 0      House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1      Ever get the feeling your life circles the rou...      0
# 2      Why the Truth Might Get You Fired October 29, ...      1
# 3      Videos 15 Civilians Killed In Single US Airstr...      1
# 4      Print \r\nAn Iranian woman has been sentenced ...      1
# ...                                                  ...    ...
# 20795  Rapper T. I. unloaded on black celebrities who...      0
# 20796  When the Green Bay Packers lost to the Washing...      0
# 20797  The Macy’s of today grew from the union of sev...      0
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...      1
# 20799    David Swanson is an author, activist, journa...      1
#
# [20800 rows x 5 columns]

# %%
vectorizer = CountVectorizer()
test = df['text']
X = vectorizer.fit_transform(test)
vectorizer.get_feature_names_out()
print(X.toarray())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\12462\Desktop\note\ENGG2112\as\Tan-ruei-ens-Untitled-project\Notebook 1.ipynb 单元格 25 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/12462/Desktop/note/ENGG2112/as/Tan-ruei-ens-Untitled-project/Notebook%201.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> vectorizer = CountVectorizer()
#       <a href='vscode-notebook-cell:/c%3A/Users/12462/Desktop/note/ENGG2112/as/Tan-ruei-ens-Untitled-project/Notebook%201.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> test = df['text']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/12462/Desktop/note/ENGG2112/as/Tan-ruei-ens-Untitled-project/Notebook%201.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> X = vectorizer.fit_transform(test)
#       <a href='vscode-notebook-cell:/c%3A/Users/12462/Desktop/note/ENGG2112/as/Tan-ruei-ens-Untitled-project/Notebook%201.ipynb#X33sZmlsZQ%3D%3D?line=3'>4</a> vectorizer.get_feature_names_out()
#       <a href='vscode-notebook-cell:/c%3A/Users/12462/Desktop/note/ENGG2112/as/Tan-ruei-ens-Untitled-project/Notebook%201.ipynb#X33sZmlsZQ%3D%3D?line=4'>5</a> print(X.toarray())
#
# File c:\Users\12462\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\12462\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:1383, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1375             warnings.warn(
#    1376                 "Upper case characters found in"
#    1377                 " vocabulary while 'lowercase'"
#    1378                 " is True. These entries will not"
#    1379                 " be matched with any documents"
#    1380             )
#    1381             break
# -> 1383 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1385 if self.binary:
#    1386     X.data.fill(1)
#
# File c:\Users\12462\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:1270, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1268 for doc in raw_documents:
#    1269     feature_counter = {}
# -> 1270     for feature in analyze(doc):
#    1271         try:
#    1272             feature_idx = vocabulary[feature]
#
# File c:\Users\12462\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:105, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#      83 """Chain together an optional series of text processing steps to go from
#      84 a single document to ngrams, with or without tokenizing or preprocessing.
#      85
#    (...)
#     101     A sequence of tokens, possibly with pairs, triples, etc.
#     102 """
#     104 if decoder is not None:
# --> 105     doc = decoder(doc)
#     106 if analyzer is not None:
#     107     doc = analyzer(doc)
#
# File c:\Users\12462\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:238, in _VectorizerMixin.decode(self, doc)
#     235     doc = doc.decode(self.encoding, self.decode_error)
#     237 if doc is np.nan:
# --> 238     raise ValueError(
#     239         "np.nan is an invalid document, expected byte or unicode string."
#     240     )
#     242 return doc
#
# ValueError: np.nan is an invalid document, expected byte or unicode string.

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(ngram_range=(1, 2), max_features=10)
test = df['text']
X = vectorizer.fit_transform(test)
text_bag = vectorizer.get_feature_names_out()
print(X.toarray())
print(text_bag)
# Out:
# [[16  4 15 ... 21 41 20]
#  [15 10 15 ... 12 49 17]
#  [31 17 16 ... 23 82 36]
#  ...
#  [16  8 11 ...  9 47 22]
#  [12  0 12 ...  0 10  6]
#  [47 19 11 ...  8 54 19]]
# ['and' 'for' 'in' 'is' 'it' 'of' 'on' 'that' 'the' 'to']

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_x_train, knn_x_test, knn_y_train, knn_y_test = train_test_split(X, df['label'], test_size=0.2, random_state=42)
knn = KNeighborsClassifier()
knn.fit(knn_x_train, knn_y_train)

knn_y_pre = knn.predict(knn_x_test)
print(knn_y_test)
print(knn_y_pre)
# Out:
# 14649    1
# 9231     1
# 6473     0
# 18736    0
# 12347    1
#         ..
# 751      0
# 2081     1
# 13241    1
# 18786    0
# 14133    1
# Name: label, Length: 4160, dtype: int64
# [1 0 0 ... 1 0 1]

# %% [markdown]
# ngram model

# %%
vectorizer = CountVectorizer(analyzer="char", ngram_range=(2, 5), max_features=10, tokenizer=None, preprocessor= None)
test = df['text']
X = vectorizer.fit_transform(test)
text_bag = vectorizer.get_feature_names_out()
print(X.toarray())
print(text_bag)
# Out:
# [[ 88 132  88 ...  96 105 110]
#  [ 79 114  76 ...  72  65  89]
#  [150 210 151 ... 151 117 176]
#  ...
#  [ 87 103  61 ... 118  79  78]
#  [ 30  29  12 ...  34  13  21]
#  [137 132  86 ... 126  69 111]]
# [' a' ' t' ' th' 'd ' 'e ' 'he' 'in' 's ' 't ' 'th']

# %%
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, df['label'], test_size=0.2, random_state=42)
gnb = GaussianNB()
y_pred = gnb.fit(X_train, y_train).predict(X_test)
print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=29de9796-73f8-4fbc-85bc-ba74d1c9abf6' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
